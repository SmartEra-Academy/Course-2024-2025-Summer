# %% [markdown]
# #     <font color='Yellow' alig ='center'>` 😊 Markdown `</font>

# %% [markdown]
# <br/>
#
# # ✅ **Text Formatting**

# %% [markdown]
# **This section is about Image Processing:**
#
# **Used**:
#
#
# *   Resize image
# *   Cropped image
# *   Rotation image
#     1. list1
#     2. list2
#
# <br>
#
# **Artificial intelligence:**
# > Machin Learning
#
# > Deep Learning
#
# <br>
#
#
#
# ```
# # for i in range(5):
#     do something
# ```
#
#
# ---
#
# <br>
#
# [Github Link](https://github.com)
#
# <br>

# %%
zoomed_image = cv2.resize(src =image_rgb,
                          dsize=(new_width, new_height),
                          interpolation=cv2.INTER_CUBIC)

# %% [markdown]
# # ✅ Latex :

# %% [markdown]
# $x^2$

# %% [markdown]
# $a*x^2 + bx+c = 0$

# %% [markdown]
# $x\ = \frac{-b}{b}$

# %% [markdown]
# <hr>
# $$X\ = \frac{-b + \sqrt(b^2 -4ac)}{2a}$$
# <hr>

# %% [markdown]
#  $s^2 = \frac{σ(x-x)^2}{n-1}$

# %% [markdown]
# $\int_1^3(x^2 + 2x-4)dx$
