# %% [markdown]
# # Data Collection

# %% [markdown]
# 1) Use [Chrome Extension](https://chrome.google.com/webstore/detail/download-all-images/nnffbdeachhbpfapjklmpnmjcgamcdmm) for collect datas from page

# %% [markdown]
# 2) use [Scrapy](https://towardsdatascience.com/using-scrapy-to-build-your-own-dataset-64ea2d7d4673) or [Selenium](https://selenium-python.readthedocs.io/) for data collection (Most use for NLP & LLM Tasks)

# %% [markdown]
# 3) use Generative AI Models

# %% [markdown]
# 4) use Datasets sites such as :
#
#   4.1) [Kaggle](https://www.kaggle.com/)
#
#   4.2) [IEEE](https://ieee-dataport.org/topic-tags/image-processing)
#
#   4.3) [Dataset Search](https://datasetsearch.research.google.com/)
#
#   4.4) [UCI](https://archive.ics.uci.edu/datasets?skip=0&take=10&sort=desc&orderBy=NumHits&search=&Types=Image)

# %% [markdown]
# 5) Papers and Connection Authers
